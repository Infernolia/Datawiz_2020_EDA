# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('practice.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sum_column = df["math score"] + df["reading score"] + df["writing score"]
df["sum_column"] = sum_column = df["math score"] + df["reading score"] + df["writing score"]

# %% [markdown]
# # Information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   sum_column                   1000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score   sum_column
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000

# %%
df["sum_column"].describe()
# Out:
# count    1000.000000
# mean      203.312000
# std        42.771978
# min        27.000000
# 25%       175.000000
# 50%       205.000000
# 75%       233.000000
# max       300.000000
# Name: sum_column, dtype: float64

# %%
df["test preparation course"].describe()
# Out:
# count     1000
# unique       2
# top       none
# freq       642
# Name: test preparation course, dtype: object

# %% [markdown]
# # gender count

# %%
male = len(df[df['gender'] == 'male'])
female = len(df[df['gender'] == 'female'])
print('Number of male :',male)
print('Number of female :',female)
# Out:
# Number of male : 482
# Number of female : 518

# %%
sns.barplot(x ="gender" , y ="sum_column" , data=df)

# %% [markdown]
# # Relation between parental level of education and total score

# %%
sns.barplot(x ="parental level of education" , y ="sum_column" , data=df)

# %%
sns.distplot(df["sum_column"], bins=16, color="purple")

# %%
sns.pairplot(df, hue='test preparation course', height=2.5);

# %%
sns.barplot(x ="test preparation course" , y ="sum_column" , data=df)

# %%
sns.pairplot(data=df, hue="lunch")

# %%
b = sns.countplot(df['race/ethnicity'])
b.axes.set_title('race/ethnicitys', fontsize = 30)
b.set_xlabel('race/ethnicity', fontsize = 20)
b.set_ylabel('Count', fontsize = 20)
plt.show()

# %%
sns.pairplot(data=df, hue="parental level of education")

# %%
sns.pairplot(data=df, hue="race/ethnicity")

# %%
labels = ['Male','Female']
sizes = [male, female]
colors = ['yellowgreen', 'gold']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels)
plt.show()
