# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Practice.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.pairplot(df, hue='gender')

# %%
sns.pairplot(df, hue='test preparation course')

# %%
sns.pairplot(df, hue='lunch')

# %%
sns.pairplot(df, hue='race/ethnicity')

# %%
sns.pairplot(df, hue='parental level of education')

# %%
sns.barplot(x='gender',y='math score', data=df)

# %%
sns.barplot(x='gender',y='reading score', data=df)

# %%
sns.barplot(x='gender',y='writing score', data=df)

# %%
data = df.copy()

# %%
data['race/ethnicity'] = data['race/ethnicity'].map({'group A':1,'group B':2,'group C':3,'group D':4,'group E':5})

# %%
data.describe()
# Out:
#        race/ethnicity  math score  reading score  writing score
# count     1000.000000  1000.00000    1000.000000    1000.000000
# mean         3.174000    66.08900      69.169000      68.054000
# std          1.157179    15.16308      14.600192      15.195657
# min          1.000000     0.00000      17.000000      10.000000
# 25%          2.000000    57.00000      59.000000      57.750000
# 50%          3.000000    66.00000      70.000000      69.000000
# 75%          4.000000    77.00000      79.000000      79.000000
# max          5.000000   100.00000     100.000000     100.000000

# %%
data['test preparation course']=data['test preparation course'].map({'completed':1,'none':0})

# %%
data.describe()
# Out:
#        race/ethnicity  test preparation course  math score  reading score  \
# count     1000.000000              1000.000000  1000.00000    1000.000000
# mean         3.174000                 0.358000    66.08900      69.169000
# std          1.157179                 0.479652    15.16308      14.600192
# min          1.000000                 0.000000     0.00000      17.000000
# 25%          2.000000                 0.000000    57.00000      59.000000
# 50%          3.000000                 0.000000    66.00000      70.000000
# 75%          4.000000                 1.000000    77.00000      79.000000
# max          5.000000                 1.000000   100.00000     100.000000
#
#        writing score
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000

# %%
sns.distplot(data['race/ethnicity'], kde=False)

# %%
sns.distplot(data['test preparation course'], kde=False)
#1-completed, 0-none

# %%
sns.distplot(data['math score'])

# %%
sns.distplot(data['reading score'])

# %%
sns.distplot(data['writing score'])

# %%
data.describe()
# Out:
#        race/ethnicity  test preparation course  math score  reading score  \
# count     1000.000000              1000.000000  1000.00000    1000.000000
# mean         3.174000                 0.358000    66.08900      69.169000
# std          1.157179                 0.479652    15.16308      14.600192
# min          1.000000                 0.000000     0.00000      17.000000
# 25%          2.000000                 0.000000    57.00000      59.000000
# 50%          3.000000                 0.000000    66.00000      70.000000
# 75%          4.000000                 1.000000    77.00000      79.000000
# max          5.000000                 1.000000   100.00000     100.000000
#
#        writing score
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000

# %%
data.describe(include='all')
# Out:
#         gender  race/ethnicity parental level of education     lunch  \
# count     1000     1000.000000                        1000      1000
# unique       2             NaN                           6         2
# top     female             NaN                some college  standard
# freq       518             NaN                         226       645
# mean       NaN        3.174000                         NaN       NaN
# std        NaN        1.157179                         NaN       NaN
# min        NaN        1.000000                         NaN       NaN
# 25%        NaN        2.000000                         NaN       NaN
# 50%        NaN        3.000000                         NaN       NaN
# 75%        NaN        4.000000                         NaN       NaN
# max        NaN        5.000000                         NaN       NaN
#
#         test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(x='test preparation course', y='math score', data=data, hue= 'gender')

# %%
sns.boxplot(x='test preparation course', y='reading score', data=data, hue= 'gender')

# %%
sns.boxplot(x='test preparation course', y='writing score', data=data, hue= 'gender')

# %% [markdown]
# NEXT PART IS DONE BY REMOVING THE OUTLIERS FROM THE COPY CREATED

# %%
q = data['writing score'].quantile(0.1) #used to remove the outliers
data_2 = data[data['writing score']>q]

# %%
sns.distplot(data_2['writing score'])

# %%
q = data['math score'].quantile(0.1)
data_2 = data[data['math score']>q]

# %%
sns.distplot(data_2['math score'])

# %%
q = data['reading score'].quantile(0.1)
data_2 = data[data['reading score']>q]

# %%
sns.distplot(data_2['reading score'])

# %%
data_2.describe()
# Out:
#        race/ethnicity  test preparation course  math score  reading score  \
# count      887.000000               887.000000  887.000000     887.000000
# mean         3.220970                 0.374295   68.776776      72.446449
# std          1.138635                 0.484213   13.258917      11.772831
# min          1.000000                 0.000000   35.000000      52.000000
# 25%          2.000000                 0.000000   60.000000      63.000000
# 50%          3.000000                 0.000000   68.000000      72.000000
# 75%          4.000000                 1.000000   78.000000      81.000000
# max          5.000000                 1.000000  100.000000     100.000000
#
#        writing score
# count     887.000000
# mean       71.285231
# std        12.568675
# min        41.000000
# 25%        62.000000
# 50%        71.000000
# 75%        80.000000
# max       100.000000

# %%
data_2.describe(include='all')
# Out:
#         gender  race/ethnicity parental level of education     lunch  \
# count      887      887.000000                         887       887
# unique       2             NaN                           6         2
# top     female             NaN          associate's degree  standard
# freq       481             NaN                         204       594
# mean       NaN        3.220970                         NaN       NaN
# std        NaN        1.138635                         NaN       NaN
# min        NaN        1.000000                         NaN       NaN
# 25%        NaN        2.000000                         NaN       NaN
# 50%        NaN        3.000000                         NaN       NaN
# 75%        NaN        4.000000                         NaN       NaN
# max        NaN        5.000000                         NaN       NaN
#
#         test preparation course  math score  reading score  writing score
# ...

# %%
sns.pairplot(data_2, hue='gender')
