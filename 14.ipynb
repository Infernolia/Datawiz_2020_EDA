# %%
import pandas as pd
csv_file = "C:\\Users\\SAIMA\\Downloads\\Practice.csv"
df = pd.read_csv(csv_file)

# %%
df['parental level of education'].value_counts().plot(kind='pie', figsize=(6,6))

# %%
df['parental level of education'].value_counts().plot(kind='bar', figsize=(6,6))

# %%
df['parental level of education'].value_counts().plot(kind='hist', figsize=(6,6))

# %%
df['parental level of education'].value_counts().plot(kind='box', figsize=(6,6))
